# %% [markdown]
# <h1>CH2 인위적 확산 EDA 및 외적 타당성 최종보고서</h1><p class='meta'>참고 보고서처럼 그래프와 해석을 포함하도록 보강했다. 필수변수 단독 EDA와 필수+보조 통합 EDA는 분리되어 있다.</p><div class='note'><b>필수변수:</b> 도로소나무비율_500m, 주거지소나무비율_300m, log1p_원목생산업체수<br><b>핵심 판정:</b> 목재 변수는 핵심 유지, 도로·주거지 변수는 구조적 핵심성이 높지만 단순 외적상관 방향 때문에 조건부 핵심 유지.</div><section><h2>요약 카드</h2><div class='cards'><div class='card'><b>도로소나무비율_500m</b><span>결측률 1.2%</span><span>0값 0.4%</span><span>왜도 1.31</span></div><div class='card'><b>주거지소나무비율_300m</b><span>결측률 1.2%</span><span>0값 2.43%</span><span>왜도 1.63</span></div><div class='card'><b>log1p_원목생산업체수</b><span>결측률 0%</span><span>0값 34.65%</span><span>왜도 0.51</span></div></div></section><section class='interpret'><h2>종합 해석</h2><p>이번 EDA는 먼저 분석에 직접 넣을 필수변수 3개만 따로 검증하고, 그 다음 보조변수를 합쳐 중복성과 대체 가능성을 확인했다. 이 분리 방식은 최종 분석 투입변수를 먼저 안정화하고, 보조변수가 핵심변수 판단을 흐리지 않게 하기 위한 것이다.</p><p><b>목재활동 변수</b>는 차년도 신규감염수와 양의 순위상관을 보여 이론 방향과 부합한다. 따라서 기본 목재 대표변수는 <code>log1p_원목생산업체수</code>가 가장 타당하다.</p><p><b>도로·주거지 노출 변수</b>는 단순 외적상관에서 음의 방향이다. 다만 이는 구조적 노출변수의 개념이 틀렸다는 뜻으로 바로 해석하면 안 된다. 소나무림 분모가 작은 도시지역, 이미 감염이 집중된 산림지역, 비선형·포화효과, 지역 규모효과가 섞였을 가능성이 크므로 조건부 핵심변수로 유지하고 다음 단계의 다변량/공간검증에서 재확인해야 한다.</p><p><b>도로밀도와 임도 변수</b>는 보조·민감도 변수로 남긴다. 도로소나무비율과 도로밀도를 동시에 기본지수에 넣으면 도로 요인이 이중 가중될 위험이 있다.</p></section><section><h2>필수변수 분포 그래프</h2><p class='interpret-text'>분포는 최종 지수 표준화 전에 결측, 0값, 우측 왜도, 비율 상한 문제를 확인하기 위한 것이다. 목재 변수는 0값이 많지만 log1p 변환으로 극단적인 업체 수 차이를 완화한다.</p><div class='grid3'><figure class='small'><figcaption>도로소나무비율_500m 분포</figcaption><svg viewBox='0 0 360 220'><line x1='34' y1='186' x2='326' y2='186' stroke='#999'/><line x1='34' y1='34' x2='34' y2='186' stroke='#999'/><rect x='35' y='155.368191721133' width='26.2' height='30.6318082788671' fill='#6b8f71'></rect><rect x='64.2' y='34' width='26.2' height='152' fill='#6b8f71'></rect><rect x='93.4' y='154.871459694989' width='26.2' height='31.1285403050109' fill='#6b8f71'></rect><rect x='122.6' y='166.958605664488' width='26.2' height='19.041394335512' fill='#6b8f71'></rect><rect x='151.8' y='161.494553376906' width='26.2' height='24.5054466230937' fill='#6b8f71'></rect><rect x='181' y='164.971677559913' width='26.2' height='21.0283224400871' fill='#6b8f71'></rect><rect x='210.2' y='169.938997821351' width='26.2' height='16.0610021786492' fill='#6b8f71'></rect><rect x='239.4' y='180.37037037037' width='26.2' height='5.62962962962963' fill='#6b8f71'></rect><rect x='268.6' y='174.740740740741' width='26.2' height='11.2592592592593' fill='#6b8f71'></rect><rect x='297.8' y='170.104575163399' width='26.2' height='15.8954248366013' fill='#6b8f71'></rect><text x='34' y='212' class='axis'>0</text><text x='296' y='212' class='axis'>1</text></svg></figure><figure class='small'><figcaption>주거지소나무비율_300m 분포</figcaption><svg viewBox='0 0 360 220'><line x1='34' y1='186' x2='326' y2='186' stroke='#999'/><line x1='34' y1='34' x2='34' y2='186' stroke='#999'/><rect x='35' y='86.3555555555556' width='26.2' height='99.6444444444444' fill='#6b8f71'></rect><rect x='64.2' y='34' width='26.2' height='152' fill='#6b8f71'></rect><rect x='93.4' y='126.888888888889' width='26.2' height='59.1111111111111' fill='#6b8f71'></rect><rect x='122.6' y='152.222222222222' width='26.2' height='33.7777777777778' fill='#6b8f71'></rect><rect x='151.8' y='169.111111111111' width='26.2' height='16.8888888888889' fill='#6b8f71'></rect><rect x='181' y='172.488888888889' width='26.2' height='13.5111111111111' fill='#6b8f71'></rect><rect x='210.2' y='170.8' width='26.2' height='15.2' fill='#6b8f71'></rect><rect x='239.4' y='180.933333333333' width='26.2' height='5.06666666666667' fill='#6b8f71'></rect><rect x='268.6' y='170.8' width='26.2' height='15.2' fill='#6b8f71'></rect><rect x='297.8' y='179.244444444444' width='26.2' height='6.75555555555556' fill='#6b8f71'></rect><text x='34' y='212' class='axis'>0</text><text x='296' y='212' class='axis'>1</text></svg></figure><figure class='small'><figcaption>log1p_원목생산업체수 분포</figcaption><svg viewBox='0 0 360 220'><line x1='34' y1='186' x2='326' y2='186' stroke='#999'/><line x1='34' y1='34' x2='34' y2='186' stroke='#999'/><rect x='35' y='34' width='26.2' height='152' fill='#6b8f71'></rect><rect x='64.2' y='134.455988455988' width='26.2' height='51.5440115440115' fill='#6b8f71'></rect><rect x='93.4' y='159.679653679654' width='26.2' height='26.3203463203463' fill='#6b8f71'></rect><rect x='122.6' y='145.203463203463' width='26.2' height='40.7965367965368' fill='#6b8f71'></rect><rect x='151.8' y='132.262626262626' width='26.2' height='53.7373737373737' fill='#6b8f71'></rect><rect x='181' y='152.880230880231' width='26.2' height='33.1197691197691' fill='#6b8f71'></rect><rect x='210.2' y='154.415584415584' width='26.2' height='31.5844155844156' fill='#6b8f71'></rect><rect x='239.4' y='161.215007215007' width='26.2' height='24.7849927849928' fill='#6b8f71'></rect><rect x='268.6' y='169.988455988456' width='26.2' height='16.011544011544' fill='#6b8f71'></rect><rect x='297.8' y='177.226551226551' width='26.2' height='8.77344877344877' fill='#6b8f71'></rect><text x='34' y='212' class='axis'>0</text><text x='296' y='212' class='axis'>4.45</text></svg></figure></div></section><section><h2>연도별 평균 추이</h2><p class='interpret-text'>도로·주거지 노출은 임상도 판 또는 사전계산 방식의 영향을 받아 실제 연도별 변화로 과해석하면 안 된다. 목재 변수는 인허가일 기반 누적형이라 증가 추세를 보일 수 있다.</p><figure><figcaption>필수변수 연도별 평균</figcaption><svg viewBox='0 0 760 280'><line x1='54' y1='238' x2='736' y2='238' stroke='#999'/><line x1='54' y1='38' x2='54' y2='238' stroke='#999'/><text x='40' y='266' class='axis'>2016</text><text x='137.428571428571' y='266' class='axis'>2017</text><text x='234.857142857143' y='266' class='axis'>2018</text><text x='332.285714285714' y='266' class='axis'>2019</text><text x='429.714285714286' y='266' class='axis'>2020</text><text x='527.142857142857' y='266' class='axis'>2021</text><text x='624.571428571429' y='266' class='axis'>2022</text><text x='722' y='266' class='axis'>2023</text><polyline points='54,108.709886966157 151.428571428571,98.2901252363849 248.857142857143,87.7769663962684 346.285714285714,66.3101832463496 443.714285714286,58.7824127322426 541.142857142857,53.2617824117046 638.571428571429,45.8527828405049 736,38' fill='none' stroke='#2f6f9f' stroke-width='2.2'/><circle cx='586' cy='38' r='5' fill='#2f6f9f'/><text x='596' y='42' class='axis'>log1p_원목생산업체수</text><polyline points='54,232.367950211647 151.428571428571,231.45641962619 248.857142857143,231.481361333299 346.285714285714,231.526310892358 443.714285714286,223.95501842079 541.142857142857,224.04161858847 638.571428571429,223.920454876844 736,223.652609084853' fill='none' stroke='#b05d3b' stroke-width='2.2'/><circle cx='586' cy='54' r='5' fill='#b05d3b'/><text x='596' y='58' class='axis'>도로소나무비율_500m</text><polyline points='54,238 151.428571428571,238 248.857142857143,238 346.285714285714,238 443.714285714286,238 541.142857142857,238 638.571428571429,238 736,238' fill='none' stroke='#6b8f71' stroke-width='2.2'/><circle cx='586' cy='70' r='5' fill='#6b8f71'/><text x='596' y='74' class='axis'>주거지소나무비율_300m</text></svg></figure></section><section><h2>필수변수 상관 heatmap</h2><p class='interpret-text'>도로와 주거지 노출은 서로 양의 상관이 높고, 목재활동은 두 노출비율과 음의 상관이다. 이는 목재활동이 도시·사업체 분포와 관련되고, 도로/주거지 소나무 비율은 산림 분포 구조와 강하게 연결되기 때문일 수 있다.</p><figure><figcaption>필수변수 Spearman 상관 heatmap</figcaption><svg viewBox='0 0 336 276'><text transform='translate(180,110) rotate(-55)' class='axis'>도로소나무비율_500m</text><text transform='translate(222,110) rotate(-55)' class='axis'>log1p_원목생산업체수</text><text transform='translate(264,110) rotate(-55)' class='axis'>주거지소나무비율_300m</text><text x='8' y='146' class='axis'>도로소나무비율_500m</text><rect x='170' y='120' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='175' y='145' class='heat'>1</text><rect x='212' y='120' width='40' height='40' fill='rgba(182,75,75,0.443748164282053)' stroke='#fff'/><text x='217' y='145' class='heat'>-0.44</text><rect x='254' y='120' width='40' height='40' fill='rgba(47,111,159,0.635281368412661)' stroke='#fff'/><text x='259' y='145' class='heat'>0.64</text><text x='8' y='188' class='axis'>log1p_원목생산업체수</text><rect x='170' y='162' width='40' height='40' fill='rgba(182,75,75,0.443748164282053)' stroke='#fff'/><text x='175' y='187' class='heat'>-0.44</text><rect x='212' y='162' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='217' y='187' class='heat'>1</text><rect x='254' y='162' width='40' height='40' fill='rgba(182,75,75,0.518464459844296)' stroke='#fff'/><text x='259' y='187' class='heat'>-0.52</text><text x='8' y='230' class='axis'>주거지소나무비율_300m</text><rect x='170' y='204' width='40' height='40' fill='rgba(47,111,159,0.635281368412661)' stroke='#fff'/><text x='175' y='229' class='heat'>0.64</text><rect x='212' y='204' width='40' height='40' fill='rgba(182,75,75,0.518464459844296)' stroke='#fff'/><text x='217' y='229' class='heat'>-0.52</text><rect x='254' y='204' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='259' y='229' class='heat'>1</text></svg></figure></section><section><h2>t+1 외적 타당성 그래프</h2><p class='interpret-text'>차년도 신규감염수와의 단순 Spearman 상관이다. 목재 변수는 이론 방향과 같은 양의 방향이다. 도로·주거지 비율은 음의 방향이므로, 노출이 낮은 지역에서 이미 감염이 집중된 구조, 도시/산림 분모효과, 비선형성을 추가 확인해야 한다.</p><figure><figcaption>차년도 신규감염수와 Spearman 상관</figcaption><svg viewBox='0 0 760 260' role='img'><text x='8' y='74.32' class='axis'>도로소나무비율_500m</text><rect x='170' y='34' width='482.531506346721' height='56' fill='#b64b4b' rx='2'></rect><text x='658.531506346721' y='74.32' class='val'>-0.192</text><text x='8' y='138.32' class='axis'>log1p_원목생산업체수</text><rect x='170' y='98' width='454.592245575923' height='56' fill='#2f6f9f' rx='2'></rect><text x='630.592245575923' y='138.32' class='val'>0.181</text><text x='8' y='202.32' class='axis'>주거지소나무비율_300m</text><rect x='170' y='162' width='560' height='56' fill='#b64b4b' rx='2'></rect><text x='736' y='202.32' class='val'>-0.223</text></svg></figure></section><section><h2>필수변수 분위별 차년도 신규감염</h2><p class='interpret-text'>분위별 평균은 선형 상관으로 놓칠 수 있는 비선형·포화효과를 보기 위한 보조 진단이다. 목재는 중상위 분위에서 증가하다 최상위에서 낮아지는 형태라, 대형 도시·대형 산림지역의 구조 차이를 함께 봐야 한다.</p><figure><figcaption>필수변수 분위별 차년도 신규감염 평균</figcaption><svg viewBox='0 0 760 280'><line x1='54' y1='238' x2='736' y2='238' stroke='#999'/><line x1='54' y1='38' x2='54' y2='238' stroke='#999'/><text x='40' y='266' class='axis'>1</text><text x='210.5' y='266' class='axis'>2</text><text x='381' y='266' class='axis'>3</text><text x='551.5' y='266' class='axis'>4</text><text x='722' y='266' class='axis'>5</text><polyline points='54,195.700219332707 224.5,153.133417434562 395,137.476466116531 565.5,134.816414511538 736,182.477606718694' fill='none' stroke='#2f6f9f' stroke-width='2.2'/><circle cx='586' cy='38' r='5' fill='#2f6f9f'/><text x='596' y='42' class='axis'>log1p_원목생산업체수</text><polyline points='54,151.190149610889 224.5,136.057526708571 395,171.593832863127 565.5,146.098607019164 736,232.266902118231' fill='none' stroke='#b05d3b' stroke-width='2.2'/><circle cx='586' cy='54' r='5' fill='#b05d3b'/><text x='596' y='58' class='axis'>도로소나무비율_500m</text><polyline points='54,197.34494759386 224.5,38 395,168.914787292728 565.5,193.792392726958 736,238' fill='none' stroke='#6b8f71' stroke-width='2.2'/><circle cx='586' cy='70' r='5' fill='#6b8f71'/><text x='596' y='74' class='axis'>주거지소나무비율_300m</text></svg></figure></section><section><h2>필수+보조 통합 상관 heatmap</h2><p class='interpret-text'>보조변수는 최종지수 투입보다 중복성 확인과 민감도 검증에 사용한다. 특히 원목생산업체수, log1p_목재업체수, log1p_제재업체수는 같은 목재활동 후보군이므로 대표변수 1개만 선택해야 한다.</p><figure><figcaption>필수+보조 통합 Spearman 상관 heatmap</figcaption><svg viewBox='0 0 756 696'><text transform='translate(180,110) rotate(-55)' class='axis'>주거지까지중앙거리_m</text><text transform='translate(222,110) rotate(-55)' class='axis'>도로까지중앙거리_m</text><text transform='translate(264,110) rotate(-55)' class='axis'>국유림임도밀도</text><text transform='translate(306,110) rotate(-55)' class='axis'>임도까지중앙거리_m</text><text transform='translate(348,110) rotate(-55)' class='axis'>log1p_목재업체수</text><text transform='translate(390,110) rotate(-55)' class='axis'>원목생산업체_존재여부</text><text transform='translate(432,110) rotate(-55)' class='axis'>log1p_제재업체수</text><text transform='translate(474,110) rotate(-55)' class='axis'>원목생산업체수</text><text transform='translate(516,110) rotate(-55)' class='axis'>도로소나무비율_500m</text><text transform='translate(558,110) rotate(-55)' class='axis'>도로밀도_km_km2</text><text transform='translate(600,110) rotate(-55)' class='axis'>국유림임도보유여부</text><text transform='translate(642,110) rotate(-55)' class='axis'>log1p_원목생산업체수</text><text transform='translate(684,110) rotate(-55)' class='axis'>주거지소나무비율_300m</text><text x='8' y='146' class='axis'>주거지까지중앙거리_m</text><rect x='170' y='120' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='175' y='145' class='heat'>1</text><rect x='212' y='120' width='40' height='40' fill='rgba(47,111,159,0.28577432810352)' stroke='#fff'/><text x='217' y='145' class='heat'>0.29</text><rect x='254' y='120' width='40' height='40' fill='rgba(47,111,159,0.310792564020218)' stroke='#fff'/><text x='259' y='145' class='heat'>0.31</text><rect x='296' y='120' width='40' height='40' fill='rgba(182,75,75,0.277673834874282)' stroke='#fff'/><text x='301' y='145' class='heat'>-0.28</text><rect x='338' y='120' width='40' height='40' fill='rgba(47,111,159,0.0970868417411808)' stroke='#fff'/><text x='343' y='145' class='heat'>0.1</text><rect x='380' y='120' width='40' height='40' fill='rgba(47,111,159,0.126377831189864)' stroke='#fff'/><text x='385' y='145' class='heat'>0.13</text><rect x='422' y='120' width='40' height='40' fill='rgba(47,111,159,0.0438925731321862)' stroke='#fff'/><text x='427' y='145' class='heat'>0.04</text><rect x='464' y='120' width='40' height='40' fill='rgba(47,111,159,0.141106854536221)' stroke='#fff'/><text x='469' y='145' class='heat'>0.14</text><rect x='506' y='120' width='40' height='40' fill='rgba(182,75,75,0.196905170991622)' stroke='#fff'/><text x='511' y='145' class='heat'>-0.2</text><rect x='548' y='120' width='40' height='40' fill='rgba(182,75,75,0.354128530460938)' stroke='#fff'/><text x='553' y='145' class='heat'>-0.35</text><rect x='590' y='120' width='40' height='40' fill='rgba(47,111,159,0.239493753982099)' stroke='#fff'/><text x='595' y='145' class='heat'>0.24</text><rect x='632' y='120' width='40' height='40' fill='rgba(47,111,159,0.141106854536221)' stroke='#fff'/><text x='637' y='145' class='heat'>0.14</text><rect x='674' y='120' width='40' height='40' fill='rgba(182,75,75,0.56095445588583)' stroke='#fff'/><text x='679' y='145' class='heat'>-0.56</text><text x='8' y='188' class='axis'>도로까지중앙거리_m</text><rect x='170' y='162' width='40' height='40' fill='rgba(47,111,159,0.28577432810352)' stroke='#fff'/><text x='175' y='187' class='heat'>0.29</text><rect x='212' y='162' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='217' y='187' class='heat'>1</text><rect x='254' y='162' width='40' height='40' fill='rgba(47,111,159,0.323676991951065)' stroke='#fff'/><text x='259' y='187' class='heat'>0.32</text><rect x='296' y='162' width='40' height='40' fill='rgba(182,75,75,0.193258784132248)' stroke='#fff'/><text x='301' y='187' class='heat'>-0.19</text><rect x='338' y='162' width='40' height='40' fill='rgba(47,111,159,0.239708022503073)' stroke='#fff'/><text x='343' y='187' class='heat'>0.24</text><rect x='380' y='162' width='40' height='40' fill='rgba(47,111,159,0.255517456601598)' stroke='#fff'/><text x='385' y='187' class='heat'>0.26</text><rect x='422' y='162' width='40' height='40' fill='rgba(47,111,159,0.199343841322583)' stroke='#fff'/><text x='427' y='187' class='heat'>0.2</text><rect x='464' y='162' width='40' height='40' fill='rgba(47,111,159,0.248764276855697)' stroke='#fff'/><text x='469' y='187' class='heat'>0.25</text><rect x='506' y='162' width='40' height='40' fill='rgba(182,75,75,0.55818177377494)' stroke='#fff'/><text x='511' y='187' class='heat'>-0.56</text><rect x='548' y='162' width='40' height='40' fill='rgba(182,75,75,0.505725019541781)' stroke='#fff'/><text x='553' y='187' class='heat'>-0.51</text><rect x='590' y='162' width='40' height='40' fill='rgba(47,111,159,0.400839849050734)' stroke='#fff'/><text x='595' y='187' class='heat'>0.4</text><rect x='632' y='162' width='40' height='40' fill='rgba(47,111,159,0.248764276855697)' stroke='#fff'/><text x='637' y='187' class='heat'>0.25</text><rect x='674' y='162' width='40' height='40' fill='rgba(182,75,75,0.313144318321512)' stroke='#fff'/><text x='679' y='187' class='heat'>-0.31</text><text x='8' y='230' class='axis'>국유림임도밀도</text><rect x='170' y='204' width='40' height='40' fill='rgba(47,111,159,0.310792564020218)' stroke='#fff'/><text x='175' y='229' class='heat'>0.31</text><rect x='212' y='204' width='40' height='40' fill='rgba(47,111,159,0.323676991951065)' stroke='#fff'/><text x='217' y='229' class='heat'>0.32</text><rect x='254' y='204' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='259' y='229' class='heat'>1</text><rect x='296' y='204' width='40' height='40' fill='rgba(182,75,75,0.677727966313188)' stroke='#fff'/><text x='301' y='229' class='heat'>-0.68</text><rect x='338' y='204' width='40' height='40' fill='rgba(47,111,159,0.593373584721622)' stroke='#fff'/><text x='343' y='229' class='heat'>0.59</text><rect x='380' y='204' width='40' height='40' fill='rgba(47,111,159,0.530109369263349)' stroke='#fff'/><text x='385' y='229' class='heat'>0.53</text><rect x='422' y='204' width='40' height='40' fill='rgba(47,111,159,0.448462576009319)' stroke='#fff'/><text x='427' y='229' class='heat'>0.45</text><rect x='464' y='204' width='40' height='40' fill='rgba(47,111,159,0.632005594041056)' stroke='#fff'/><text x='469' y='229' class='heat'>0.63</text><rect x='506' y='204' width='40' height='40' fill='rgba(182,75,75,0.517743211041278)' stroke='#fff'/><text x='511' y='229' class='heat'>-0.52</text><rect x='548' y='204' width='40' height='40' fill='rgba(182,75,75,0.64065606229759)' stroke='#fff'/><text x='553' y='229' class='heat'>-0.64</text><rect x='590' y='204' width='40' height='40' fill='rgba(47,111,159,0.92975909508339)' stroke='#fff'/><text x='595' y='229' class='heat'>0.93</text><rect x='632' y='204' width='40' height='40' fill='rgba(47,111,159,0.632005594041056)' stroke='#fff'/><text x='637' y='229' class='heat'>0.63</text><rect x='674' y='204' width='40' height='40' fill='rgba(182,75,75,0.614910814104831)' stroke='#fff'/><text x='679' y='229' class='heat'>-0.61</text><text x='8' y='272' class='axis'>임도까지중앙거리_m</text><rect x='170' y='246' width='40' height='40' fill='rgba(182,75,75,0.277673834874282)' stroke='#fff'/><text x='175' y='271' class='heat'>-0.28</text><rect x='212' y='246' width='40' height='40' fill='rgba(182,75,75,0.193258784132248)' stroke='#fff'/><text x='217' y='271' class='heat'>-0.19</text><rect x='254' y='246' width='40' height='40' fill='rgba(182,75,75,0.677727966313188)' stroke='#fff'/><text x='259' y='271' class='heat'>-0.68</text><rect x='296' y='246' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='301' y='271' class='heat'>1</text><rect x='338' y='246' width='40' height='40' fill='rgba(182,75,75,0.372733815154175)' stroke='#fff'/><text x='343' y='271' class='heat'>-0.37</text><rect x='380' y='246' width='40' height='40' fill='rgba(182,75,75,0.326837281625999)' stroke='#fff'/><text x='385' y='271' class='heat'>-0.33</text><rect x='422' y='246' width='40' height='40' fill='rgba(182,75,75,0.238659113305854)' stroke='#fff'/><text x='427' y='271' class='heat'>-0.24</text><rect x='464' y='246' width='40' height='40' fill='rgba(182,75,75,0.412528893472467)' stroke='#fff'/><text x='469' y='271' class='heat'>-0.41</text><rect x='506' y='246' width='40' height='40' fill='rgba(47,111,159,0.202457511343961)' stroke='#fff'/><text x='511' y='271' class='heat'>0.2</text><rect x='548' y='246' width='40' height='40' fill='rgba(47,111,159,0.351350176132191)' stroke='#fff'/><text x='553' y='271' class='heat'>0.35</text><rect x='590' y='246' width='40' height='40' fill='rgba(182,75,75,0.566646370774381)' stroke='#fff'/><text x='595' y='271' class='heat'>-0.57</text><rect x='632' y='246' width='40' height='40' fill='rgba(182,75,75,0.412528893472467)' stroke='#fff'/><text x='637' y='271' class='heat'>-0.41</text><rect x='674' y='246' width='40' height='40' fill='rgba(47,111,159,0.356692614565547)' stroke='#fff'/><text x='679' y='271' class='heat'>0.36</text><text x='8' y='314' class='axis'>log1p_목재업체수</text><rect x='170' y='288' width='40' height='40' fill='rgba(47,111,159,0.0970868417411808)' stroke='#fff'/><text x='175' y='313' class='heat'>0.1</text><rect x='212' y='288' width='40' height='40' fill='rgba(47,111,159,0.239708022503073)' stroke='#fff'/><text x='217' y='313' class='heat'>0.24</text><rect x='254' y='288' width='40' height='40' fill='rgba(47,111,159,0.593373584721622)' stroke='#fff'/><text x='259' y='313' class='heat'>0.59</text><rect x='296' y='288' width='40' height='40' fill='rgba(182,75,75,0.372733815154175)' stroke='#fff'/><text x='301' y='313' class='heat'>-0.37</text><rect x='338' y='288' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='343' y='313' class='heat'>1</text><rect x='380' y='288' width='40' height='40' fill='rgba(47,111,159,0.756061524437537)' stroke='#fff'/><text x='385' y='313' class='heat'>0.76</text><rect x='422' y='288' width='40' height='40' fill='rgba(47,111,159,0.860267376891845)' stroke='#fff'/><text x='427' y='313' class='heat'>0.86</text><rect x='464' y='288' width='40' height='40' fill='rgba(47,111,159,0.914358278099395)' stroke='#fff'/><text x='469' y='313' class='heat'>0.91</text><rect x='506' y='288' width='40' height='40' fill='rgba(182,75,75,0.461999002890469)' stroke='#fff'/><text x='511' y='313' class='heat'>-0.46</text><rect x='548' y='288' width='40' height='40' fill='rgba(182,75,75,0.50701098123337)' stroke='#fff'/><text x='553' y='313' class='heat'>-0.51</text><rect x='590' y='288' width='40' height='40' fill='rgba(47,111,159,0.599691093964246)' stroke='#fff'/><text x='595' y='313' class='heat'>0.6</text><rect x='632' y='288' width='40' height='40' fill='rgba(47,111,159,0.914358278099395)' stroke='#fff'/><text x='637' y='313' class='heat'>0.91</text><rect x='674' y='288' width='40' height='40' fill='rgba(182,75,75,0.473187554292017)' stroke='#fff'/><text x='679' y='313' class='heat'>-0.47</text><text x='8' y='356' class='axis'>원목생산업체_존재여부</text><rect x='170' y='330' width='40' height='40' fill='rgba(47,111,159,0.126377831189864)' stroke='#fff'/><text x='175' y='355' class='heat'>0.13</text><rect x='212' y='330' width='40' height='40' fill='rgba(47,111,159,0.255517456601598)' stroke='#fff'/><text x='217' y='355' class='heat'>0.26</text><rect x='254' y='330' width='40' height='40' fill='rgba(47,111,159,0.530109369263349)' stroke='#fff'/><text x='259' y='355' class='heat'>0.53</text><rect x='296' y='330' width='40' height='40' fill='rgba(182,75,75,0.326837281625999)' stroke='#fff'/><text x='301' y='355' class='heat'>-0.33</text><rect x='338' y='330' width='40' height='40' fill='rgba(47,111,159,0.756061524437537)' stroke='#fff'/><text x='343' y='355' class='heat'>0.76</text><rect x='380' y='330' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='385' y='355' class='heat'>1</text><rect x='422' y='330' width='40' height='40' fill='rgba(47,111,159,0.559358919769324)' stroke='#fff'/><text x='427' y='355' class='heat'>0.56</text><rect x='464' y='330' width='40' height='40' fill='rgba(47,111,159,0.842870068650443)' stroke='#fff'/><text x='469' y='355' class='heat'>0.84</text><rect x='506' y='330' width='40' height='40' fill='rgba(182,75,75,0.418094391969847)' stroke='#fff'/><text x='511' y='355' class='heat'>-0.42</text><rect x='548' y='330' width='40' height='40' fill='rgba(182,75,75,0.482679294936502)' stroke='#fff'/><text x='553' y='355' class='heat'>-0.48</text><rect x='590' y='330' width='40' height='40' fill='rgba(47,111,159,0.544936751755204)' stroke='#fff'/><text x='595' y='355' class='heat'>0.54</text><rect x='632' y='330' width='40' height='40' fill='rgba(47,111,159,0.842870068650443)' stroke='#fff'/><text x='637' y='355' class='heat'>0.84</text><rect x='674' y='330' width='40' height='40' fill='rgba(182,75,75,0.47950387954282)' stroke='#fff'/><text x='679' y='355' class='heat'>-0.48</text><text x='8' y='398' class='axis'>log1p_제재업체수</text><rect x='170' y='372' width='40' height='40' fill='rgba(47,111,159,0.0438925731321862)' stroke='#fff'/><text x='175' y='397' class='heat'>0.04</text><rect x='212' y='372' width='40' height='40' fill='rgba(47,111,159,0.199343841322583)' stroke='#fff'/><text x='217' y='397' class='heat'>0.2</text><rect x='254' y='372' width='40' height='40' fill='rgba(47,111,159,0.448462576009319)' stroke='#fff'/><text x='259' y='397' class='heat'>0.45</text><rect x='296' y='372' width='40' height='40' fill='rgba(182,75,75,0.238659113305854)' stroke='#fff'/><text x='301' y='397' class='heat'>-0.24</text><rect x='338' y='372' width='40' height='40' fill='rgba(47,111,159,0.860267376891845)' stroke='#fff'/><text x='343' y='397' class='heat'>0.86</text><rect x='380' y='372' width='40' height='40' fill='rgba(47,111,159,0.559358919769324)' stroke='#fff'/><text x='385' y='397' class='heat'>0.56</text><rect x='422' y='372' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='427' y='397' class='heat'>1</text><rect x='464' y='372' width='40' height='40' fill='rgba(47,111,159,0.637688603853941)' stroke='#fff'/><text x='469' y='397' class='heat'>0.64</text><rect x='506' y='372' width='40' height='40' fill='rgba(182,75,75,0.403806204729598)' stroke='#fff'/><text x='511' y='397' class='heat'>-0.4</text><rect x='548' y='372' width='40' height='40' fill='rgba(182,75,75,0.396822505670622)' stroke='#fff'/><text x='553' y='397' class='heat'>-0.4</text><rect x='590' y='372' width='40' height='40' fill='rgba(47,111,159,0.472209109561561)' stroke='#fff'/><text x='595' y='397' class='heat'>0.47</text><rect x='632' y='372' width='40' height='40' fill='rgba(47,111,159,0.637688603853941)' stroke='#fff'/><text x='637' y='397' class='heat'>0.64</text><rect x='674' y='372' width='40' height='40' fill='rgba(182,75,75,0.349390549432598)' stroke='#fff'/><text x='679' y='397' class='heat'>-0.35</text><text x='8' y='440' class='axis'>원목생산업체수</text><rect x='170' y='414' width='40' height='40' fill='rgba(47,111,159,0.141106854536221)' stroke='#fff'/><text x='175' y='439' class='heat'>0.14</text><rect x='212' y='414' width='40' height='40' fill='rgba(47,111,159,0.248764276855697)' stroke='#fff'/><text x='217' y='439' class='heat'>0.25</text><rect x='254' y='414' width='40' height='40' fill='rgba(47,111,159,0.632005594041056)' stroke='#fff'/><text x='259' y='439' class='heat'>0.63</text><rect x='296' y='414' width='40' height='40' fill='rgba(182,75,75,0.412528893472467)' stroke='#fff'/><text x='301' y='439' class='heat'>-0.41</text><rect x='338' y='414' width='40' height='40' fill='rgba(47,111,159,0.914358278099395)' stroke='#fff'/><text x='343' y='439' class='heat'>0.91</text><rect x='380' y='414' width='40' height='40' fill='rgba(47,111,159,0.842870068650443)' stroke='#fff'/><text x='385' y='439' class='heat'>0.84</text><rect x='422' y='414' width='40' height='40' fill='rgba(47,111,159,0.637688603853941)' stroke='#fff'/><text x='427' y='439' class='heat'>0.64</text><rect x='464' y='414' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='469' y='439' class='heat'>1</text><rect x='506' y='414' width='40' height='40' fill='rgba(182,75,75,0.443748164282053)' stroke='#fff'/><text x='511' y='439' class='heat'>-0.44</text><rect x='548' y='414' width='40' height='40' fill='rgba(182,75,75,0.520113456335529)' stroke='#fff'/><text x='553' y='439' class='heat'>-0.52</text><rect x='590' y='414' width='40' height='40' fill='rgba(47,111,159,0.619140795672766)' stroke='#fff'/><text x='595' y='439' class='heat'>0.62</text><rect x='632' y='414' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='637' y='439' class='heat'>1</text><rect x='674' y='414' width='40' height='40' fill='rgba(182,75,75,0.518464459844296)' stroke='#fff'/><text x='679' y='439' class='heat'>-0.52</text><text x='8' y='482' class='axis'>도로소나무비율_500m</text><rect x='170' y='456' width='40' height='40' fill='rgba(182,75,75,0.196905170991622)' stroke='#fff'/><text x='175' y='481' class='heat'>-0.2</text><rect x='212' y='456' width='40' height='40' fill='rgba(182,75,75,0.55818177377494)' stroke='#fff'/><text x='217' y='481' class='heat'>-0.56</text><rect x='254' y='456' width='40' height='40' fill='rgba(182,75,75,0.517743211041278)' stroke='#fff'/><text x='259' y='481' class='heat'>-0.52</text><rect x='296' y='456' width='40' height='40' fill='rgba(47,111,159,0.202457511343961)' stroke='#fff'/><text x='301' y='481' class='heat'>0.2</text><rect x='338' y='456' width='40' height='40' fill='rgba(182,75,75,0.461999002890469)' stroke='#fff'/><text x='343' y='481' class='heat'>-0.46</text><rect x='380' y='456' width='40' height='40' fill='rgba(182,75,75,0.418094391969847)' stroke='#fff'/><text x='385' y='481' class='heat'>-0.42</text><rect x='422' y='456' width='40' height='40' fill='rgba(182,75,75,0.403806204729598)' stroke='#fff'/><text x='427' y='481' class='heat'>-0.4</text><rect x='464' y='456' width='40' height='40' fill='rgba(182,75,75,0.443748164282053)' stroke='#fff'/><text x='469' y='481' class='heat'>-0.44</text><rect x='506' y='456' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='511' y='481' class='heat'>1</text><rect x='548' y='456' width='40' height='40' fill='rgba(47,111,159,0.876092796442216)' stroke='#fff'/><text x='553' y='481' class='heat'>0.88</text><rect x='590' y='456' width='40' height='40' fill='rgba(182,75,75,0.570670366513152)' stroke='#fff'/><text x='595' y='481' class='heat'>-0.57</text><rect x='632' y='456' width='40' height='40' fill='rgba(182,75,75,0.443748164282053)' stroke='#fff'/><text x='637' y='481' class='heat'>-0.44</text><rect x='674' y='456' width='40' height='40' fill='rgba(47,111,159,0.635281368412661)' stroke='#fff'/><text x='679' y='481' class='heat'>0.64</text><text x='8' y='524' class='axis'>도로밀도_km_km2</text><rect x='170' y='498' width='40' height='40' fill='rgba(182,75,75,0.354128530460938)' stroke='#fff'/><text x='175' y='523' class='heat'>-0.35</text><rect x='212' y='498' width='40' height='40' fill='rgba(182,75,75,0.505725019541781)' stroke='#fff'/><text x='217' y='523' class='heat'>-0.51</text><rect x='254' y='498' width='40' height='40' fill='rgba(182,75,75,0.64065606229759)' stroke='#fff'/><text x='259' y='523' class='heat'>-0.64</text><rect x='296' y='498' width='40' height='40' fill='rgba(47,111,159,0.351350176132191)' stroke='#fff'/><text x='301' y='523' class='heat'>0.35</text><rect x='338' y='498' width='40' height='40' fill='rgba(182,75,75,0.50701098123337)' stroke='#fff'/><text x='343' y='523' class='heat'>-0.51</text><rect x='380' y='498' width='40' height='40' fill='rgba(182,75,75,0.482679294936502)' stroke='#fff'/><text x='385' y='523' class='heat'>-0.48</text><rect x='422' y='498' width='40' height='40' fill='rgba(182,75,75,0.396822505670622)' stroke='#fff'/><text x='427' y='523' class='heat'>-0.4</text><rect x='464' y='498' width='40' height='40' fill='rgba(182,75,75,0.520113456335529)' stroke='#fff'/><text x='469' y='523' class='heat'>-0.52</text><rect x='506' y='498' width='40' height='40' fill='rgba(47,111,159,0.876092796442216)' stroke='#fff'/><text x='511' y='523' class='heat'>0.88</text><rect x='548' y='498' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='553' y='523' class='heat'>1</text><rect x='590' y='498' width='40' height='40' fill='rgba(182,75,75,0.654607683947184)' stroke='#fff'/><text x='595' y='523' class='heat'>-0.65</text><rect x='632' y='498' width='40' height='40' fill='rgba(182,75,75,0.520113456335529)' stroke='#fff'/><text x='637' y='523' class='heat'>-0.52</text><rect x='674' y='498' width='40' height='40' fill='rgba(47,111,159,0.747866023047675)' stroke='#fff'/><text x='679' y='523' class='heat'>0.75</text><text x='8' y='566' class='axis'>국유림임도보유여부</text><rect x='170' y='540' width='40' height='40' fill='rgba(47,111,159,0.239493753982099)' stroke='#fff'/><text x='175' y='565' class='heat'>0.24</text><rect x='212' y='540' width='40' height='40' fill='rgba(47,111,159,0.400839849050734)' stroke='#fff'/><text x='217' y='565' class='heat'>0.4</text><rect x='254' y='540' width='40' height='40' fill='rgba(47,111,159,0.92975909508339)' stroke='#fff'/><text x='259' y='565' class='heat'>0.93</text><rect x='296' y='540' width='40' height='40' fill='rgba(182,75,75,0.566646370774381)' stroke='#fff'/><text x='301' y='565' class='heat'>-0.57</text><rect x='338' y='540' width='40' height='40' fill='rgba(47,111,159,0.599691093964246)' stroke='#fff'/><text x='343' y='565' class='heat'>0.6</text><rect x='380' y='540' width='40' height='40' fill='rgba(47,111,159,0.544936751755204)' stroke='#fff'/><text x='385' y='565' class='heat'>0.54</text><rect x='422' y='540' width='40' height='40' fill='rgba(47,111,159,0.472209109561561)' stroke='#fff'/><text x='427' y='565' class='heat'>0.47</text><rect x='464' y='540' width='40' height='40' fill='rgba(47,111,159,0.619140795672766)' stroke='#fff'/><text x='469' y='565' class='heat'>0.62</text><rect x='506' y='540' width='40' height='40' fill='rgba(182,75,75,0.570670366513152)' stroke='#fff'/><text x='511' y='565' class='heat'>-0.57</text><rect x='548' y='540' width='40' height='40' fill='rgba(182,75,75,0.654607683947184)' stroke='#fff'/><text x='553' y='565' class='heat'>-0.65</text><rect x='590' y='540' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='595' y='565' class='heat'>1</text><rect x='632' y='540' width='40' height='40' fill='rgba(47,111,159,0.619140795672766)' stroke='#fff'/><text x='637' y='565' class='heat'>0.62</text><rect x='674' y='540' width='40' height='40' fill='rgba(182,75,75,0.591779759856462)' stroke='#fff'/><text x='679' y='565' class='heat'>-0.59</text><text x='8' y='608' class='axis'>log1p_원목생산업체수</text><rect x='170' y='582' width='40' height='40' fill='rgba(47,111,159,0.141106854536221)' stroke='#fff'/><text x='175' y='607' class='heat'>0.14</text><rect x='212' y='582' width='40' height='40' fill='rgba(47,111,159,0.248764276855697)' stroke='#fff'/><text x='217' y='607' class='heat'>0.25</text><rect x='254' y='582' width='40' height='40' fill='rgba(47,111,159,0.632005594041056)' stroke='#fff'/><text x='259' y='607' class='heat'>0.63</text><rect x='296' y='582' width='40' height='40' fill='rgba(182,75,75,0.412528893472467)' stroke='#fff'/><text x='301' y='607' class='heat'>-0.41</text><rect x='338' y='582' width='40' height='40' fill='rgba(47,111,159,0.914358278099395)' stroke='#fff'/><text x='343' y='607' class='heat'>0.91</text><rect x='380' y='582' width='40' height='40' fill='rgba(47,111,159,0.842870068650443)' stroke='#fff'/><text x='385' y='607' class='heat'>0.84</text><rect x='422' y='582' width='40' height='40' fill='rgba(47,111,159,0.637688603853941)' stroke='#fff'/><text x='427' y='607' class='heat'>0.64</text><rect x='464' y='582' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='469' y='607' class='heat'>1</text><rect x='506' y='582' width='40' height='40' fill='rgba(182,75,75,0.443748164282053)' stroke='#fff'/><text x='511' y='607' class='heat'>-0.44</text><rect x='548' y='582' width='40' height='40' fill='rgba(182,75,75,0.520113456335529)' stroke='#fff'/><text x='553' y='607' class='heat'>-0.52</text><rect x='590' y='582' width='40' height='40' fill='rgba(47,111,159,0.619140795672766)' stroke='#fff'/><text x='595' y='607' class='heat'>0.62</text><rect x='632' y='582' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='637' y='607' class='heat'>1</text><rect x='674' y='582' width='40' height='40' fill='rgba(182,75,75,0.518464459844296)' stroke='#fff'/><text x='679' y='607' class='heat'>-0.52</text><text x='8' y='650' class='axis'>주거지소나무비율_300m</text><rect x='170' y='624' width='40' height='40' fill='rgba(182,75,75,0.56095445588583)' stroke='#fff'/><text x='175' y='649' class='heat'>-0.56</text><rect x='212' y='624' width='40' height='40' fill='rgba(182,75,75,0.313144318321512)' stroke='#fff'/><text x='217' y='649' class='heat'>-0.31</text><rect x='254' y='624' width='40' height='40' fill='rgba(182,75,75,0.614910814104831)' stroke='#fff'/><text x='259' y='649' class='heat'>-0.61</text><rect x='296' y='624' width='40' height='40' fill='rgba(47,111,159,0.356692614565547)' stroke='#fff'/><text x='301' y='649' class='heat'>0.36</text><rect x='338' y='624' width='40' height='40' fill='rgba(182,75,75,0.473187554292017)' stroke='#fff'/><text x='343' y='649' class='heat'>-0.47</text><rect x='380' y='624' width='40' height='40' fill='rgba(182,75,75,0.47950387954282)' stroke='#fff'/><text x='385' y='649' class='heat'>-0.48</text><rect x='422' y='624' width='40' height='40' fill='rgba(182,75,75,0.349390549432598)' stroke='#fff'/><text x='427' y='649' class='heat'>-0.35</text><rect x='464' y='624' width='40' height='40' fill='rgba(182,75,75,0.518464459844296)' stroke='#fff'/><text x='469' y='649' class='heat'>-0.52</text><rect x='506' y='624' width='40' height='40' fill='rgba(47,111,159,0.635281368412661)' stroke='#fff'/><text x='511' y='649' class='heat'>0.64</text><rect x='548' y='624' width='40' height='40' fill='rgba(47,111,159,0.747866023047675)' stroke='#fff'/><text x='553' y='649' class='heat'>0.75</text><rect x='590' y='624' width='40' height='40' fill='rgba(182,75,75,0.591779759856462)' stroke='#fff'/><text x='595' y='649' class='heat'>-0.59</text><rect x='632' y='624' width='40' height='40' fill='rgba(182,75,75,0.518464459844296)' stroke='#fff'/><text x='637' y='649' class='heat'>-0.52</text><rect x='674' y='624' width='40' height='40' fill='rgba(47,111,159,1)' stroke='#fff'/><text x='679' y='649' class='heat'>1</text></svg></figure></section><section><h2>전체 후보변수 인벤토리</h2><div class='table-wrap'><table><thead><tr><th>variable</th><th>label</th><th>category</th><th>subcategory</th><th>role</th><th>unit</th><th>expected_direction</th><th>temporal_type</th><th>source</th><th>status</th><th>reason</th><th>limit</th></tr></thead><tbody><tr><td>도로소나무비율_500m</td><td>도로소나무비율(500m)</td><td>인위적 확산</td><td>도로 노출</td><td>필수 후보</td><td>비율</td><td>값 클수록 위험 증가</td><td>임상도 판별 구간변수</td><td>인위적확산_변수_최종.csv</td><td>SELECTED_CORE_CONDITIONAL</td><td>도로 인접 소나무림이라는 인위적 이동 경로의 구조적 노출을 직접 표현한다.</td><td>단순 외적상관은 음의 방향. 도시/소나무림 분모/기존 감염분포 교란 가능성 때문에 다변량 단계에서 확인 필요.</td></tr><tr><td>주거지소나무비율_300m</td><td>주거지소나무비율(300m)</td><td>인위적 확산</td><td>생활권 노출</td><td>필수 후보</td><td>비율</td><td>값 클수록 위험 증가</td><td>단일 또는 구간 노출변수</td><td>인위적확산_변수_최종.csv</td><td>SELECTED_CORE_CONDITIONAL</td><td>생활권과 소나무림 접촉 가능성을 직접 나타내는 핵심 메커니즘이다.</td><td>단순 외적상관은 음의 방향. 주거지 자료 provenance와 단일스냅샷 한계가 있어 수동검토 유지.</td></tr><tr><td>log1p_원목생산업체수</td><td>log1p 원목생산업체수</td><td>인위적 확산</td><td>목재활동</td><td>필수 후보</td><td>log1p(count)</td><td>값 클수록 위험 증가</td><td>인허가일 기반 누적형</td><td>목재 원자료</td><td>SELECTED_CORE</td><td>목재 생산&#183;이동 활동을 가장 직접적으로 나타내고 차년도 신규감염과 Spearman 양의 방향을 보인다.</td><td>폐업일 부재, 미매핑 잔여, 현재 등록자료 기반이라는 한계.</td></tr><tr><td>도로밀도_km_km2</td><td>도로밀도(km/km&#178;)</td><td>인위적 확산</td><td>도로 접근성</td><td>보조</td><td>km/km&#178;</td><td>값 클수록 노출 증가</td><td>2023 단일 도로망 반복</td><td>인위적확산_변수_최종.csv</td><td>SELECTED_AUXILIARY</td><td>도로 접근성 설명에는 유용하지만 도로소나무비율과 동시 투입 시 도로 요인 이중가중 우려가 있다.</td><td>기본지수에는 넣지 않고 EDA/민감도용.</td></tr><tr><td>국유림임도보유여부</td><td>국유림임도보유여부</td><td>인위적 확산</td><td>임도/관리 접근성</td><td>보조</td><td>0/1</td><td>해석 보조</td><td>정적 또는 반복형</td><td>인위적확산_변수_최종.csv</td><td>SELECTED_AUXILIARY</td><td>관리&#183;접근성 맥락을 설명할 수 있으나 인위적 확산 직접 노출로 보기에는 약하다.</td><td>분석 투입 기본변수에서는 제외.</td></tr><tr><td>국유림임도밀도</td><td>국유림임도밀도</td><td>인위적 확산</td><td>임도/관리 접근성</td><td>보조</td><td>density</td><td>해석 보조</td><td>패널/정적 혼합</td><td>eda_features</td><td>SELECTED_AUXILIARY</td><td>국유림임도보유여부보다 연속적인 보조 진단 가능.</td><td>직접 확산 노출보다는 관리환경 보조변수.</td></tr><tr><td>원목생산업체수</td><td>원목생산업체수</td><td>인위적 확산</td><td>목재활동</td><td>해석/민감도</td><td>count</td><td>값 클수록 위험 증가</td><td>인허가일 기반 누적형</td><td>목재 원자료</td><td>SENSITIVITY_ONLY</td><td>원자료 해석에 필요하지만 왜도가 커서 기본 후보는 log1p 변환값을 우선한다.</td><td>log1p_원목생산업체수와 동시 투입 금지.</td></tr><tr><td>원목생산업체_존재여부</td><td>원목생산업체 존재여부</td><td>인위적 확산</td><td>목재활동</td><td>민감도</td><td>0/1</td><td>1이면 위험 증가</td><td>인허가일 기반 누적형</td><td>목재 원자료</td><td>SENSITIVITY_ONLY</td><td>목재 count의 0값/극단값 문제가 클 때 대체 후보.</td><td>규모효과를 잃는다.</td></tr><tr><td>log1p_제재업체수</td><td>log1p 제재업체수</td><td>인위적 확산</td><td>목재활동</td><td>보조</td><td>log1p(count)</td><td>값 클수록 위험 증가</td><td>인허가일 기반 누적형</td><td>목재 원자료</td><td>SELECTED_AUXILIARY</td><td>제재업은 원목생산업보다 직접성은 낮지만 목재활동 보조 후보로 의미가 있다.</td><td>원목생산업 대표변수와 중복 가능.</td></tr><tr><td>log1p_목재업체수</td><td>log1p 목재업체수</td><td>인위적 확산</td><td>목재활동</td><td>대체 후보</td><td>log1p(count)</td><td>값 클수록 위험 증가</td><td>인허가일 기반 누적형</td><td>목재 원자료</td><td>SENSITIVITY_ONLY</td><td>producer 분류 신뢰도가 흔들릴 때 넓은 목재활동 대체변수.</td><td>개념이 넓어져 직접성이 낮아질 수 있다.</td></tr><tr><td>도로까지중앙거리_m</td><td>도로까지 중앙거리</td><td>인위적 확산</td><td>도로 접근성</td><td>보조</td><td>m</td><td>값 클수록 위험 감소</td><td>패널 변수</td><td>eda_features</td><td>SELECTED_AUXILIARY</td><td>도로소나무비율의 보조 검증용 거리 지표.</td><td>방향 반전 처리가 필요하며 기본지수에는 미포함.</td></tr><tr><td>임도까지중앙거리_m</td><td>임도까지 중앙거리</td><td>인위적 확산</td><td>임도 접근성</td><td>보조</td><td>m</td><td>값 클수록 위험 감소</td><td>패널 변수</td><td>eda_features</td><td>SELECTED_AUXILIARY</td><td>임도 접근성 보조 검증.</td><td>직접 인위적 확산 필수변수는 아님.</td></tr><tr><td>주거지까지중앙거리_m</td><td>주거지까지 중앙거리</td><td>인위적 확산</td><td>생활권 접근성</td><td>보조</td><td>m</td><td>값 클수록 위험 감소</td><td>패널 변수</td><td>eda_features</td><td>SELECTED_AUXILIARY</td><td>주거지소나무비율의 보조 검증용 거리 지표.</td><td>방향 반전 처리가 필요하며 기본지수에는 미포함.</td></tr></tbody></table></div></section>
# <section><h2>필수변수 EDA 기술통계</h2><div class='table-wrap'><table><thead><tr><th>변수명</th><th>관측행수</th><th>유효값수</th><th>결측수</th><th>결측률</th><th>영값수</th><th>영값비율</th><th>음수수</th><th>평균</th><th>표준편차</th><th>최솟값</th><th>Q25</th><th>중앙값</th><th>Q75</th><th>최댓값</th><th>왜도</th><th>IQR_상한초과수</th><th>상위1퍼센트값</th></tr></thead><tbody><tr><td>도로소나무비율_500m</td><td>2000</td><td>1976</td><td>24</td><td>0.012</td><td>8</td><td>0.00404858299595142</td><td>0</td><td>0.309711564684717</td><td>0.254188124798468</td><td>0</td><td>0.140843496</td><td>0.185218104</td><td>0.44932205075</td><td>1</td><td>1.30793585360001</td><td>92</td><td>1</td></tr><tr><td>주거지소나무비율_300m</td><td>2000</td><td>1976</td><td>24</td><td>0.012</td><td>48</td><td>0.0242914979757085</td><td>0</td><td>0.243513395506073</td><td>0.226633854262253</td><td>0</td><td>0.102771872</td><td>0.16493513</td><td>0.303213039</td><td>1</td><td>1.6308260928857</td><td>200</td><td>0.990382163</td></tr><tr><td>log1p_원목생산업체수</td><td>2000</td><td>2000</td><td>0</td><td>0</td><td>693</td><td>0.3465</td><td>0</td><td>1.33630614762973</td><td>1.27210734858707</td><td>0</td><td>0</td><td>1.09861228866811</td><td>2.30258509299405</td><td>4.45434729625351</td><td>0.511631407097407</td><td>0</td><td>4.17438726989564</td></tr></tbody></table></div></section>
# <section><h2>필수변수 외적 타당성 상관</h2><div class='table-wrap'><table><thead><tr><th>설명변수</th><th>결과변수</th><th>유효쌍수</th><th>Pearson상관</th><th>Spearman상관</th><th>설명변수평균</th><th>결과변수평균</th></tr></thead><tbody><tr><td>도로소나무비율_500m</td><td>신규감염수_동년</td><td>1976</td><td>-0.0846609157593237</td><td>-0.185758137506473</td><td>0.309711564684717</td><td>1609.21356275304</td></tr><tr><td>도로소나무비율_500m</td><td>신규감염수_차년도</td><td>1729</td><td>-0.0917478662231437</td><td>-0.192497219972685</td><td>0.305866046846154</td><td>1545.57721226142</td></tr><tr><td>log1p_원목생산업체수</td><td>신규감염수_동년</td><td>2000</td><td>0.0174412525707372</td><td>0.177985042758572</td><td>1.33630614762973</td><td>1589.903</td></tr><tr><td>log1p_원목생산업체수</td><td>신규감염수_차년도</td><td>1750</td><td>0.0195681124447252</td><td>0.181351357048232</td><td>1.30698639163294</td><td>1527.03028571429</td></tr><tr><td>주거지소나무비율_300m</td><td>신규감염수_동년</td><td>1976</td><td>-0.0996168326416793</td><td>-0.216272098309414</td><td>0.243513395506073</td><td>1609.21356275304</td></tr><tr><td>주거지소나무비율_300m</td><td>신규감염수_차년도</td><td>1729</td><td>-0.108867813029689</td><td>-0.223401874834771</td><td>0.243513395506073</td><td>1545.57721226142</td></tr></tbody></table></div></section>
# <section><h2>전체 후보변수 최종선정표</h2><div class='table-wrap'><table><thead><tr><th>category</th><th>subcategory</th><th>variable</th><th>variable_label</th><th>role</th><th>temporal_type</th><th>expected_direction</th><th>missing_rate</th><th>zero_rate</th><th>skewness</th><th>external_outcome</th><th>spearman_external</th><th>pearson_external</th><th>reverse_causality_risk</th><th>leakage_risk</th><th>data_quality_grade</th><th>conceptual_relevance_grade</th><th>external_validity_grade</th><th>final_status</th><th>final_role</th><th>selection_reason</th><th>limitations</th><th>recommended_transformation</th><th>recommended_standardization_block</th></tr></thead><tbody><tr><td>인위적 확산</td><td>도로 노출</td><td>도로소나무비율_500m</td><td>도로소나무비율(500m)</td><td>필수 후보</td><td>임상도 판별 구간변수</td><td>값 클수록 위험 증가</td><td>0.012</td><td>0.00404858299595142</td><td>1.30793585360001</td><td>차년도 신규감염수</td><td>-0.192497219972685</td><td>-0.0917478662231437</td><td>low_to_medium</td><td>low</td><td>CONDITIONAL</td><td>PASS</td><td>CONDITIONAL_REVIEW</td><td>SELECTED_CORE_CONDITIONAL</td><td>필수 후보</td><td>도로 인접 소나무림이라는 인위적 이동 경로의 구조적 노출을 직접 표현한다.</td><td>단순 외적상관은 음의 방향. 도시/소나무림 분모/기존 감염분포 교란 가능성 때문에 다변량 단계에서 확인 필요.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>생활권 노출</td><td>주거지소나무비율_300m</td><td>주거지소나무비율(300m)</td><td>필수 후보</td><td>단일 또는 구간 노출변수</td><td>값 클수록 위험 증가</td><td>0.012</td><td>0.0242914979757085</td><td>1.6308260928857</td><td>차년도 신규감염수</td><td>-0.223401874834771</td><td>-0.108867813029689</td><td>low_to_medium</td><td>low</td><td>CONDITIONAL</td><td>PASS</td><td>CONDITIONAL_REVIEW</td><td>SELECTED_CORE_CONDITIONAL</td><td>필수 후보</td><td>생활권과 소나무림 접촉 가능성을 직접 나타내는 핵심 메커니즘이다.</td><td>단순 외적상관은 음의 방향. 주거지 자료 provenance와 단일스냅샷 한계가 있어 수동검토 유지.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>목재활동</td><td>log1p_원목생산업체수</td><td>log1p 원목생산업체수</td><td>필수 후보</td><td>인허가일 기반 누적형</td><td>값 클수록 위험 증가</td><td>0</td><td>0.3465</td><td>0.511631407097407</td><td>차년도 신규감염수</td><td>0.181351357048232</td><td>0.0195681124447252</td><td>low_to_medium</td><td>low</td><td>CONDITIONAL</td><td>PASS</td><td>PASS</td><td>SELECTED_CORE</td><td>필수 후보</td><td>목재 생산&#183;이동 활동을 가장 직접적으로 나타내고 차년도 신규감염과 Spearman 양의 방향을 보인다.</td><td>폐업일 부재, 미매핑 잔여, 현재 등록자료 기반이라는 한계.</td><td>already_log1p</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>도로 접근성</td><td>도로밀도_km_km2</td><td>도로밀도(km/km&#178;)</td><td>보조</td><td>2023 단일 도로망 반복</td><td>값 클수록 노출 증가</td><td>0</td><td>0.004</td><td>1.9742096891723</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>도로 접근성 설명에는 유용하지만 도로소나무비율과 동시 투입 시 도로 요인 이중가중 우려가 있다.</td><td>기본지수에는 넣지 않고 EDA/민감도용.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>임도/관리 접근성</td><td>국유림임도보유여부</td><td>국유림임도보유여부</td><td>보조</td><td>정적 또는 반복형</td><td>해석 보조</td><td>0.012</td><td>0.510121457489879</td><td>0.0404633919826133</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>관리&#183;접근성 맥락을 설명할 수 있으나 인위적 확산 직접 노출로 보기에는 약하다.</td><td>분석 투입 기본변수에서는 제외.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>임도/관리 접근성</td><td>국유림임도밀도</td><td>국유림임도밀도</td><td>보조</td><td>패널/정적 혼합</td><td>해석 보조</td><td>0.012</td><td>0.510121457489879</td><td>2.212195935228</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>국유림임도보유여부보다 연속적인 보조 진단 가능.</td><td>직접 확산 노출보다는 관리환경 보조변수.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>목재활동</td><td>원목생산업체수</td><td>원목생산업체수</td><td>해석/민감도</td><td>인허가일 기반 누적형</td><td>값 클수록 위험 증가</td><td>0</td><td>0.3465</td><td>2.65563460689784</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SENSITIVITY_ONLY</td><td>해석/민감도</td><td>원자료 해석에 필요하지만 왜도가 커서 기본 후보는 log1p 변환값을 우선한다.</td><td>log1p_원목생산업체수와 동시 투입 금지.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>목재활동</td><td>원목생산업체_존재여부</td><td>원목생산업체 존재여부</td><td>민감도</td><td>인허가일 기반 누적형</td><td>1이면 위험 증가</td><td>0</td><td>0.3465</td><td>-0.644671034823266</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SENSITIVITY_ONLY</td><td>민감도</td><td>목재 count의 0값/극단값 문제가 클 때 대체 후보.</td><td>규모효과를 잃는다.</td><td>raw</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>목재활동</td><td>log1p_제재업체수</td><td>log1p 제재업체수</td><td>보조</td><td>인허가일 기반 누적형</td><td>값 클수록 위험 증가</td><td>0</td><td>0.2975</td><td>0.345490275166092</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>제재업은 원목생산업보다 직접성은 낮지만 목재활동 보조 후보로 의미가 있다.</td><td>원목생산업 대표변수와 중복 가능.</td><td>already_log1p</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>목재활동</td><td>log1p_목재업체수</td><td>log1p 목재업체수</td><td>대체 후보</td><td>인허가일 기반 누적형</td><td>값 클수록 위험 증가</td><td>0</td><td>0.2205</td><td>0.0494017919303422</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SENSITIVITY_ONLY</td><td>대체 후보</td><td>producer 분류 신뢰도가 흔들릴 때 넓은 목재활동 대체변수.</td><td>개념이 넓어져 직접성이 낮아질 수 있다.</td><td>already_log1p</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>도로 접근성</td><td>도로까지중앙거리_m</td><td>도로까지 중앙거리</td><td>보조</td><td>패널 변수</td><td>값 클수록 위험 감소</td><td>0.534</td><td>0</td><td>5.4173904648827</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>도로소나무비율의 보조 검증용 거리 지표.</td><td>방향 반전 처리가 필요하며 기본지수에는 미포함.</td><td>direction_reverse_if_used</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>임도 접근성</td><td>임도까지중앙거리_m</td><td>임도까지 중앙거리</td><td>보조</td><td>패널 변수</td><td>값 클수록 위험 감소</td><td>0.534</td><td>0</td><td>0.952722807228471</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>임도 접근성 보조 검증.</td><td>직접 인위적 확산 필수변수는 아님.</td><td>direction_reverse_if_used</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr><tr><td>인위적 확산</td><td>생활권 접근성</td><td>주거지까지중앙거리_m</td><td>주거지까지 중앙거리</td><td>보조</td><td>패널 변수</td><td>값 클수록 위험 감소</td><td>0.534</td><td>0</td><td>5.63259374792131</td><td>차년도 신규감염수</td><td></td><td></td><td>low_to_medium</td><td>low</td><td>PASS</td><td>CONDITIONAL</td><td>NOT_PRIMARY</td><td>SELECTED_AUXILIARY</td><td>보조</td><td>주거지소나무비율의 보조 검증용 거리 지표.</td><td>방향 반전 처리가 필요하며 기본지수에는 미포함.</td><td>direction_reverse_if_used</td><td>지수 생성 단계에서 방향 통일 후 표준화</td></tr></tbody></table></div></section>
# <section><h2>기본&#183;최소&#183;확장 조합 제안</h2><div class='table-wrap'><table><thead><tr><th>조합</th><th>포함변수</th><th>제외_보조</th><th>이유</th><th>한계</th></tr></thead><tbody><tr><td>기본지수</td><td>도로소나무비율_500m; 주거지소나무비율_300m; log1p_원목생산업체수</td><td>도로밀도_km_km2; 국유림임도보유여부; 거리변수; 목재 대체 후보</td><td>세 핵심 메커니즘을 하나씩 대표. 도로/생활권/목재활동의 이중가중을 최소화.</td><td>도로&#183;주거지 변수의 단순 외적상관 방향은 추가 다변량 검토 필요</td></tr><tr><td>최소지수</td><td>도로소나무비율_500m; 주거지소나무비율_300m; log1p_원목생산업체수</td><td>모든 보조변수</td><td>인위적 확산 메커니즘 3개를 가장 단순하게 표현</td><td>임도/도로밀도 등 접근성 맥락은 빠짐</td></tr><tr><td>확장지수_검토용</td><td>기본지수 + 도로밀도_km_km2 또는 국유림임도밀도 중 1개만 민감도</td><td>중복 목재변수 동시투입 제외</td><td>접근성 맥락 보강 가능</td><td>도로 요인 이중가중 위험</td></tr></tbody></table></div></section>
